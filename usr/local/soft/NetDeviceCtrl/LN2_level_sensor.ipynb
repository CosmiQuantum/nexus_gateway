# %%
from NetDrivers import NetDevice
ln = NetDevice(server_ip="192.168.0.201",server_port=7180)
ln.getIdentity()
# Out:
# ['AMERICAN MAGNETICS INC.', 'MODEL 1700', '1700-20-184', '2.5.17116']

# %%
ln._sendCmd("MEASure:N2:LEVel?",getResponse=True,verbose=False)
# Out:
# ['30897.129']

# %%
ln._sendCmd("N2:UNIT?")
# Out:
# ['%']

# %%
ln._sendCmd("MEASure:N2:LEVel?",getResponse=True,verbose=False)
# Out:
# ['30897.129']

# %%
ln._sendCmd("MEASure:N2:LEVel?N2:UNIT",getResponse=True,verbose=False)
# Out:
# ['-8']

# %%
ln._sendCmd("MEASure:N2:LEVel?",getResponse=True,verbose=False)
